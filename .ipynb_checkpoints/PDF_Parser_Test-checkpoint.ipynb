# %%
import re
import os
import json
from PIL import Image
import io
import numpy as np
import cv2
from utils import *
from matplotlib import pyplot as plt

# %%
data_folder = './data'
pdf_files = [data_folder + '/' + filename for filename in os.listdir('data/') if '.pdf' in filename]

# %%
config = {
    "username":"user1",
    "projectName":"testProject",
    "filepath":"./data/2.pdf"
}

# %%
doc = fitz.open("./data/5.pdf")

# %%
page = list(doc.pages())[4]

# %%
content = page.get_text('dict')

# %%
blocks = content["blocks"]

# %%
for i, block in enumerate(blocks):
    if block["type"] == 0:
        print(i)
        print(block["bbox"])
        print(len(block))
# Out:
# 0
# (150.0, 59.87000274658203, 517.6799926757812, 87.20999908447266)
# 1
# (149.99993896484375, 97.87000274658203, 521.3299560546875, 265.2099914550781)
# 2
# (89.99400329589844, 277.5639953613281, 197.3459930419922, 294.0879821777344)
# 3
# (89.99598693847656, 299.9739990234375, 112.22598266601562, 313.7440185546875)
# 4
# (149.9959716796875, 317.8739929199219, 522.6859130859375, 429.2139892578125)
# 5
# (89.99595642089844, 441.9739990234375, 166.6759490966797, 455.7440185546875)
# 6
# (149.99594116210938, 459.8739929199219, 516.0560302734375, 557.2139892578125)
# 7
# (89.99597930908203, 569.9739990234375, 209.4859619140625, 583.7440185546875)
# 8
# (149.99594116210938, 587.8740234375, 519.075927734375, 685.2140502929688)
# 9
# (78.0, 36.29597091674805, 522.0, 46.96800231933594)
# 10
# (177.23199462890625, 712.9760131835938, 380.7760009765625, 723.6480102539062)
# 11
# (18.176000595092773, 75.26399230957031, 34.66400146484375, 680.73583984375)

# %%
matrix = fitz.Matrix(1, 1)
page_img = page.get_pixmap(matrix = matrix)
img_bytes = page_img.tobytes()
img_np = np.frombuffer(img_bytes, dtype=np.uint8)
img_cv = cv2.imdecode(img_np, flags=1)
img_cv.shape
# Out:
# (792, 612, 3)

# %%
def make_clusters(blocks, diff=5):

    def match_cluster(bbox, cluster):
        left = bbox[0]
        right = bbox[2]
        cluster_left = cluster["bboxes"][:, 0].mean()
        cluster_right = cluster["bboxes"][:, 2].mean()
        res = (abs(left - cluster_left) < diff) and (abs(right - cluster_right) < diff)
        return res

    clusters = []
    for i, block in enumerate(blocks):
        bbox = block["bbox"]
        is_matched = False
        for cluster in clusters:
            if match_cluster(bbox, cluster):
                cluster["bboxes"] = np.vstack((cluster["bboxes"], np.array(bbox)[np.newaxis]))
                cluster["lines_count"] += len(block["lines"])
                is_matched = True
                break
        if not is_matched:
            cluster = dict()
            cluster["bboxes"] = np.array(bbox)[np.newaxis]
            cluster["lines_count"] = len(block["lines"])
            clusters.append(cluster)
    return clusters

# %%
def get_text_bboxes(page, min_lines=15, diff=5): # rewrite: get actual text bbox for 
    content = page.get_text('dict')
    clusters = make_clusters(content["blocks"], diff=diff)
    clusters = [
        cluster for cluster in clusters if cluster["lines_count"] >= min_lines
    ]
    for cluster in clusters:
        cluster["left"] = cluster["bboxes"][:, 0].min()
        cluster["right"] = cluster["bboxes"][:, 1].min()
        cluster["top"] = cluster["bboxes"][:, 2].max()
        cluster["bottom"] = cluster["bboxes"][:, 3].max()
    return clusters

# %%
clusters = get_text_bboxes(page)
for cluster in clusters:
    #print(cluster)
    print(bbox)
    print(cluster["lines_count"])
    img_draw = cv2.rectangle(img_cv.copy(), (int(cluster["left"]), int(cluster["top"])), 
                                            (int(cluster["right"]), int(cluster["bottom"])), 
                                             (0, 0, 255), 2))

    plt.figure(figsize=(15, 15))
    plt.imshow(img_draw)
    plt.show()
# Out:
# [ 18.1760006   75.26399231  34.66400146 680.73583984]
# 36
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_451299/3969403928.py in <module>
#       4     print(bbox)
#       5     print(cluster["lines_count"])
# ----> 6     img_draw = cv2.rectangle(img_cv.copy(), (int(cluster["left"]), int(cluster["top"]),
#       7                                             (int(cluster["right"]), int(cluster["bottom"])),
#       8                                              (0, 0, 255), 2))
#
# error: OpenCV(4.5.4) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - rectangle() missing required argument 'pt2' (pos 3)
# >  - rectangle() missing required argument 'pt2' (pos 3)
# >  - rectangle() missing required argument 'color' (pos 3)
# >  - rectangle() missing required argument 'color' (pos 3)

# %%
for i in range(len(content["blocks"])):
    for line in content["blocks"][i]["lines"]:
        for span in line["spans"]:
            if "Protandim" in span["text"]:
                print(i, span)
# Out:
# 0 {'size': 7.970200061798096, 'flags': 4, 'font': 'AdvPSFT-L', 'color': 2236191, 'ascender': 0.7699999809265137, 'descender': -0.23899999260902405, 'text': 'Protandim (Prot) and ﬁsh oil (FO), metformin (Met), or with the', 'origin': (43.087440490722656, 234.0828857421875), 'bbox': (43.087440490722656, 227.94583129882812, 286.9086608886719, 235.98776245117188)}
# 0 {'size': 7.970200061798096, 'flags': 4, 'font': 'AdvPSFT-L', 'color': 2236191, 'ascender': 0.7699999809265137, 'descender': -0.23899999260902405, 'text': 'Protandim (Prot) is a mixture of ﬁve botanical extracts, including', 'origin': (53.061344146728516, 475.1950378417969), 'bbox': (53.061344146728516, 469.0579833984375, 286.90948486328125, 477.09991455078125)}
# 2 {'size': 6.973800182342529, 'flags': 4, 'font': 'AdvPSFT-L', 'color': 2236191, 'ascender': 0.7699999809265137, 'descender': -0.23899999260902405, 'text': '17aE2, Protandim, NDGA, ACA and lifespan, R. Strong', 'origin': (367.08648681640625, 34.80938720703125), 'bbox': (367.08648681640625, 29.43956184387207, 532.7542114257812, 36.47612380981445)}

# %%
content["blocks"][1]
# Out:
# {'number': 1,
#  'type': 0,
#  'bbox': (306.70574951171875,
#   52.498722076416016,
#   550.5912475585938,
#   707.2135009765625),
#  'lines': [{'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'translation (Dowling',
#      'origin': (306.70574951171875, 58.72344970703125),
#      'bbox': (306.70574951171875,
#       52.586395263671875,
#       377.6875915527344,
#       60.628326416015625)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (377.6875915527344, 58.72344970703125),
#      'bbox': (377.6875915527344,
#       52.498722076416016,
#       400.1045837402344,
#       60.628326416015625)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2007). Studies in both vertebrates and',
#      'origin': (400.079833984375, 58.72344970703125),
#      'bbox': (400.079833984375,
#       52.586395263671875,
#       550.5164184570312,
#       60.628326416015625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70574951171875,
#     52.498722076416016,
#     550.5164184570312,
#     60.628326416015625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'invertebrates have been reported showing that Met increases longevity.',
#      'origin': (306.70654296875, 69.72235107421875),
#      'bbox': (306.70654296875,
#       63.585296630859375,
#       550.5675659179688,
#       71.62722778320312)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70654296875,
#     63.585296630859375,
#     550.5675659179688,
#     71.62722778320312)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'For example, Met was recently shown to extend both the lifespan and',
#      'origin': (306.70654296875, 80.663818359375),
#      'bbox': (306.70654296875,
#       74.52676391601562,
#       550.514892578125,
#       82.56869506835938)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70654296875,
#     74.52676391601562,
#     550.514892578125,
#     82.56869506835938)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'healthspan of the nematode',
#      'origin': (306.70654296875, 91.60528564453125),
#      'bbox': (306.70654296875,
#       85.46823120117188,
#       404.9719543457031,
#       93.51016235351562)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' C. elegans',
#      'origin': (404.9719543457031, 91.60528564453125),
#      'bbox': (404.9719543457031,
#       85.38056182861328,
#       443.5556640625,
#       93.51016235351562)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ' (Onken & Driscoll, 2010). Met',
#      'origin': (443.5556640625, 91.60528564453125),
#      'bbox': (443.5556640625,
#       85.46823120117188,
#       550.5165405273438,
#       93.51016235351562)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70654296875,
#     85.38056182861328,
#     550.5165405273438,
#     93.51016235351562)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'has also been shown to extend the lifespan of short-lived, tumor-prone,',
#      'origin': (306.7085876464844, 102.557373046875),
#      'bbox': (306.7085876464844,
#       96.42031860351562,
#       550.514404296875,
#       104.46224975585938)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7085876464844,
#     96.42031860351562,
#     550.514404296875,
#     104.46224975585938)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'HER2/neu mice and female SHR outbred mice (Anisimov',
#      'origin': (306.7085876464844, 113.5562744140625),
#      'bbox': (306.7085876464844,
#       107.41921997070312,
#       502.56756591796875,
#       115.46115112304688)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (502.56756591796875, 113.5562744140625),
#      'bbox': (502.56756591796875,
#       107.33155059814453,
#       523.13134765625,
#       115.46115112304688)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2005).',
#      'origin': (523.1058959960938, 113.5562744140625),
#      'bbox': (523.1058959960938,
#       107.41921997070312,
#       550.5687255859375,
#       115.46115112304688)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7085876464844,
#     107.33155059814453,
#     550.5687255859375,
#     115.46115112304688)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'More recently, de Cabo and colleagues reported that 0.1% Met in the',
#      'origin': (306.7085876464844, 124.49774169921875),
#      'bbox': (306.7085876464844,
#       118.36068725585938,
#       550.530517578125,
#       126.40261840820312)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7085876464844,
#     118.36068725585938,
#     550.530517578125,
#     126.40261840820312)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'diet (i.e. at 1000 ppm) increased mean lifespan by 4',
#      'origin': (306.7085876464844, 135.439208984375),
#      'bbox': (306.7085876464844,
#       129.30215454101562,
#       481.5285339355469,
#       137.34408569335938)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvTTec369687+20',
#      'color': 2236191,
#      'ascender': 0.8640000224113464,
#      'descender': -0.20800000429153442,
#      'text': '–',
#      'origin': (481.49346923828125, 135.439208984375),
#      'bbox': (481.49346923828125,
#       128.55296325683594,
#       485.47857666015625,
#       137.09701538085938)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '6% in male C57BL/',
#      'origin': (485.4618225097656, 135.439208984375),
#      'bbox': (485.4618225097656,
#       129.30215454101562,
#       550.53369140625,
#       137.34408569335938)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7085876464844,
#     128.55296325683594,
#     550.53369140625,
#     137.34408569335938)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '6J.Nia mice (Martin-Montalvo',
#      'origin': (306.70855712890625, 146.43731689453125),
#      'bbox': (306.70855712890625,
#       140.30026245117188,
#       407.0446472167969,
#       148.34219360351562)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (407.0446472167969, 146.43731689453125),
#      'bbox': (407.0446472167969,
#       140.21258544921875,
#       426.8665466308594,
#       148.34219360351562)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2013) and also improved indices of',
#      'origin': (426.84100341796875, 146.43731689453125),
#      'bbox': (426.84100341796875,
#       140.30026245117188,
#       550.5136108398438,
#       148.34219360351562)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     140.21258544921875,
#     550.5136108398438,
#     148.34219360351562)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'health. Female mice were not tested in the de Cabo study. Conversely, a',
#      'origin': (306.70855712890625, 157.3787841796875),
#      'bbox': (306.70855712890625,
#       151.24172973632812,
#       550.5066528320312,
#       159.28366088867188)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     151.24172973632812,
#     550.5066528320312,
#     159.28366088867188)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'study of Met on the lifespan of Fisher-344 rats found no effect on',
#      'origin': (306.70855712890625, 168.32025146484375),
#      'bbox': (306.70855712890625,
#       162.18319702148438,
#       550.5016479492188,
#       170.22512817382812)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     162.18319702148438,
#     550.5016479492188,
#     170.22512817382812)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'lifespan (Smith',
#      'origin': (306.70855712890625, 179.318359375),
#      'bbox': (306.70855712890625,
#       173.18130493164062,
#       356.9367980957031,
#       181.22323608398438)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (356.9367980957031, 179.318359375),
#      'bbox': (356.9367980957031,
#       173.0936279296875,
#       377.0328674316406,
#       181.22323608398438)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2010).',
#      'origin': (377.00732421875, 179.318359375),
#      'bbox': (377.00732421875,
#       173.18130493164062,
#       404.01666259765625,
#       181.22323608398438)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     173.0936279296875,
#     404.01666259765625,
#     181.22323608398438)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Rapamycin (Rapa) and Met each inhibit mTORC1, but through distinct',
#      'origin': (316.6856689453125, 190.25982666015625),
#      'bbox': (316.6856689453125,
#       184.12277221679688,
#       550.5503540039062,
#       192.16470336914062)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (316.6856689453125,
#     184.12277221679688,
#     550.5503540039062,
#     192.16470336914062)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'mechanisms. In addition, Rapa affects glucose tolerance through',
#      'origin': (306.707763671875, 201.2012939453125),
#      'bbox': (306.707763671875,
#       195.06423950195312,
#       550.5257568359375,
#       203.10617065429688)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     195.06423950195312,
#     550.5257568359375,
#     203.10617065429688)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'inhibition of a second mTOR complex, mTORC2, resulting in hepatic',
#      'origin': (306.707763671875, 212.14276123046875),
#      'bbox': (306.707763671875,
#       206.00570678710938,
#       550.552001953125,
#       214.04763793945312)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     206.00570678710938,
#     550.552001953125,
#     214.04763793945312)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'insulin resistance (Lamming',
#      'origin': (306.707763671875, 223.14166259765625),
#      'bbox': (306.707763671875,
#       217.00460815429688,
#       403.1918640136719,
#       225.04653930664062)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (403.1918640136719, 223.14166259765625),
#      'bbox': (403.1918640136719,
#       216.91693115234375,
#       424.9377746582031,
#       225.04653930664062)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ' 2013), while Met acts to activate',
#      'origin': (424.9377746582031, 223.14166259765625),
#      'bbox': (424.9377746582031,
#       217.00460815429688,
#       550.5360717773438,
#       225.04653930664062)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     216.91693115234375,
#     550.5360717773438,
#     225.04653930664062)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'AMPK, suppressing hepatic glucose output (DeFronzo',
#      'origin': (306.7070007324219, 234.0831298828125),
#      'bbox': (306.7070007324219,
#       227.94607543945312,
#       487.60015869140625,
#       235.98800659179688)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (487.60015869140625, 234.0831298828125),
#      'bbox': (487.60015869140625,
#       227.8583984375,
#       507.1424255371094,
#       235.98800659179688)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 1991; Zhou',
#      'origin': (507.11688232421875, 234.0831298828125),
#      'bbox': (507.11688232421875,
#       227.94607543945312,
#       550.5496215820312,
#       235.98800659179688)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     227.8583984375,
#     550.5496215820312,
#     235.98800659179688)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': 'et al.',
#      'origin': (306.7070007324219, 245.02459716796875),
#      'bbox': (306.7070007324219,
#       238.79986572265625,
#       324.19366455078125,
#       246.92947387695312)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2001). Met would be expected to diminish the negative effects of',
#      'origin': (324.2254943847656, 245.02459716796875),
#      'bbox': (324.2254943847656,
#       238.88754272460938,
#       550.5120849609375,
#       246.92947387695312)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     238.79986572265625,
#     550.5120849609375,
#     246.92947387695312)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Rapa on hepatic glucose output and thus potentially lead to a survival',
#      'origin': (306.7070007324219, 256.02349853515625),
#      'bbox': (306.7070007324219,
#       249.88644409179688,
#       550.5335693359375,
#       257.9283752441406)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     249.88644409179688,
#     550.5335693359375,
#     257.9283752441406)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'beneﬁt greater than that produced by Rapa alone.',
#      'origin': (306.7070007324219, 266.9649658203125),
#      'bbox': (306.7070007324219,
#       260.8279113769531,
#       479.9025573730469,
#       268.8698425292969)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     260.8279113769531,
#     479.9025573730469,
#     268.8698425292969)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Ursodeoxycholic acid (UDCA) was chosen for testing because bile',
#      'origin': (316.6849060058594, 277.9064636230469),
#      'bbox': (316.6849060058594,
#       271.7694091796875,
#       550.49951171875,
#       279.81134033203125)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (316.6849060058594,
#     271.7694091796875,
#     550.49951171875,
#     279.81134033203125)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'acids (BAs), endogenous products of cholesterol catabolism, have been',
#      'origin': (306.7070007324219, 288.90533447265625),
#      'bbox': (306.7070007324219,
#       282.7682800292969,
#       550.53369140625,
#       290.8102111816406)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     282.7682800292969,
#     550.53369140625,
#     290.8102111816406)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'reported to be associated with increased xenobiotic detoxiﬁcation gene',
#      'origin': (306.7070007324219, 299.8468322753906),
#      'bbox': (306.7070007324219,
#       293.70977783203125,
#       550.5328369140625,
#       301.751708984375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     293.70977783203125,
#     550.5328369140625,
#     301.751708984375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'expression in long-lived rodents (e.g. Amador-Noguez',
#      'origin': (306.7070007324219, 310.788330078125),
#      'bbox': (306.7070007324219,
#       304.6512756347656,
#       499.8241271972656,
#       312.6932067871094)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (499.8241271972656, 310.788330078125),
#      'bbox': (499.8241271972656,
#       304.5635986328125,
#       521.769287109375,
#       312.6932067871094)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2007).',
#      'origin': (521.7437744140625, 310.788330078125),
#      'bbox': (521.7437744140625,
#       304.6512756347656,
#       550.5679321289062,
#       312.6932067871094)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     304.5635986328125,
#     550.5679321289062,
#     312.6932067871094)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Moreover, in a clinical trial UDCA prevented colorectal adenoma',
#      'origin': (306.70697021484375, 321.7864074707031),
#      'bbox': (306.70697021484375,
#       315.64935302734375,
#       550.5912475585938,
#       323.6912841796875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     315.64935302734375,
#     550.5912475585938,
#     323.6912841796875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'recurrence (Alberts',
#      'origin': (306.70697021484375, 332.7279052734375),
#      'bbox': (306.70697021484375,
#       326.5908508300781,
#       370.3976745605469,
#       334.6327819824219)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (370.3976745605469, 332.7279052734375),
#      'bbox': (370.3976745605469,
#       326.503173828125,
#       389.78759765625,
#       334.6327819824219)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2005). UDCA treatment suppressed chemically',
#      'origin': (389.7620544433594, 332.7279052734375),
#      'bbox': (389.7620544433594,
#       326.5908508300781,
#       550.5313110351562,
#       334.6327819824219)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     326.503173828125,
#     550.5313110351562,
#     334.6327819824219)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'induced diabetes in rats (Lukivskaya',
#      'origin': (306.7070007324219, 343.6694030761719),
#      'bbox': (306.7070007324219,
#       337.5323486328125,
#       432.59954833984375,
#       345.57427978515625)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (432.59954833984375, 343.6694030761719),
#      'bbox': (432.59954833984375,
#       337.4446716308594,
#       453.6241149902344,
#       345.57427978515625)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2004). Thus, UDCA has a',
#      'origin': (453.59857177734375, 343.6694030761719),
#      'bbox': (453.59857177734375,
#       337.5323486328125,
#       550.5050048828125,
#       345.57427978515625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.7070007324219,
#     337.4446716308594,
#     550.5050048828125,
#     345.57427978515625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'number of properties that suggested it might have anti-aging effects,',
#      'origin': (306.70697021484375, 354.61090087890625),
#      'bbox': (306.70697021484375,
#       348.4738464355469,
#       550.51611328125,
#       356.5157775878906)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     348.4738464355469,
#     550.51611328125,
#     356.5157775878906)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'including increased xenobiotic stress resistance, protection from meta-',
#      'origin': (306.70697021484375, 365.6089782714844),
#      'bbox': (306.70697021484375,
#       359.471923828125,
#       550.5631103515625,
#       367.51385498046875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     359.471923828125,
#     550.5631103515625,
#     367.51385498046875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'bolic derangements such as diabetes, and suppression of tumor',
#      'origin': (306.70697021484375, 376.55047607421875),
#      'bbox': (306.70697021484375,
#       370.4134216308594,
#       550.5407104492188,
#       378.4553527832031)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     370.4134216308594,
#     550.5407104492188,
#     378.4553527832031)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'formation.',
#      'origin': (306.70697021484375, 387.4919738769531),
#      'bbox': (306.70697021484375,
#       381.35491943359375,
#       342.4692687988281,
#       389.3968505859375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     381.35491943359375,
#     342.4692687988281,
#     389.3968505859375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Nordihydroguaiaretic (NDGA) is produced by the leaves of the',
#      'origin': (316.68487548828125, 398.4908447265625),
#      'bbox': (316.68487548828125,
#       392.3537902832031,
#       550.528076171875,
#       400.3957214355469)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (316.68487548828125,
#     392.3537902832031,
#     550.528076171875,
#     400.3957214355469)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'creosote bush (',
#      'origin': (306.70697021484375, 409.4323425292969),
#      'bbox': (306.70697021484375,
#       403.2952880859375,
#       362.2950744628906,
#       411.33721923828125)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': 'Larrea tridentata',
#      'origin': (362.3230285644531, 409.4323425292969),
#      'bbox': (362.3230285644531,
#       403.2076110839844,
#       420.43304443359375,
#       411.33721923828125)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '). It is both a lipoxygenase inhibitor',
#      'origin': (420.3771667480469, 409.4323425292969),
#      'bbox': (420.3771667480469,
#       403.2952880859375,
#       550.5439453125,
#       411.33721923828125)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70697021484375,
#     403.2076110839844,
#     550.5439453125,
#     411.33721923828125)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'and potent antioxidant. In earlier reports, it was shown to increase',
#      'origin': (306.707763671875, 420.37384033203125),
#      'bbox': (306.707763671875,
#       414.2367858886719,
#       550.5416259765625,
#       422.2787170410156)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     414.2367858886719,
#     550.5416259765625,
#     422.2787170410156)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'median lifespan, but only in male mice (Strong',
#      'origin': (306.707763671875, 431.3719177246094),
#      'bbox': (306.707763671875,
#       425.23486328125,
#       472.54852294921875,
#       433.27679443359375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (472.54852294921875, 431.3719177246094),
#      'bbox': (472.54852294921875,
#       425.1471862792969,
#       493.4798889160156,
#       433.27679443359375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2008; Harrison',
#      'origin': (493.45513916015625, 431.3719177246094),
#      'bbox': (493.45513916015625,
#       425.23486328125,
#       550.5750122070312,
#       433.27679443359375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     425.1471862792969,
#     550.5750122070312,
#     433.27679443359375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': 'et al.',
#      'origin': (306.707763671875, 442.31341552734375),
#      'bbox': (306.707763671875,
#       436.08868408203125,
#       324.1944274902344,
#       444.2182922363281)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2014). The sex difference was tentatively attributed to differences',
#      'origin': (324.22625732421875, 442.31341552734375),
#      'bbox': (324.22625732421875,
#       436.1763610839844,
#       550.5535888671875,
#       444.2182922363281)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     436.08868408203125,
#     550.5535888671875,
#     444.2182922363281)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'in pharmacokinetics, as male mice maintained higher trough blood levels',
#      'origin': (306.707763671875, 453.2549133300781),
#      'bbox': (306.707763671875,
#       447.11785888671875,
#       550.5377807617188,
#       455.1597900390625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     447.11785888671875,
#     550.5377807617188,
#     455.1597900390625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'of NDGA than females. To test this interpretation, and to deﬁne the',
#      'origin': (306.707763671875, 464.2537841796875),
#      'bbox': (306.707763671875,
#       458.1167297363281,
#       550.5289916992188,
#       466.1586608886719)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     458.1167297363281,
#     550.5289916992188,
#     466.1586608886719)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'optimal NDGA concentration for lifespan extension in males, we',
#      'origin': (306.707763671875, 475.1952819824219),
#      'bbox': (306.707763671875,
#       469.0582275390625,
#       550.4939575195312,
#       477.10015869140625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     469.0582275390625,
#     550.4939575195312,
#     477.10015869140625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'repeated the study starting at 6 months of age at the dose used in',
#      'origin': (306.707763671875, 486.13677978515625),
#      'bbox': (306.707763671875,
#       479.9997253417969,
#       550.501708984375,
#       488.0416564941406)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     479.9997253417969,
#     550.501708984375,
#     488.0416564941406)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'the original study, 2500 ppm, plus doses higher (5000 ppm) and lower',
#      'origin': (306.707763671875, 497.0782775878906),
#      'bbox': (306.707763671875,
#       490.94122314453125,
#       550.5558471679688,
#       498.983154296875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     490.94122314453125,
#     550.5558471679688,
#     498.983154296875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '(800 ppm) than tested previously. An interim survival analysis was',
#      'origin': (306.707763671875, 508.0771484375),
#      'bbox': (306.707763671875,
#       501.9400939941406,
#       550.5011596679688,
#       509.9820251464844)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     501.9400939941406,
#     550.5011596679688,
#     509.9820251464844)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'published (Harrison',
#      'origin': (306.707763671875, 519.0186767578125),
#      'bbox': (306.707763671875,
#       512.8816528320312,
#       371.62347412109375,
#       520.923583984375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (371.62347412109375, 519.0186767578125),
#      'bbox': (371.62347412109375,
#       512.7939453125,
#       391.03570556640625,
#       520.923583984375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2014), reporting the effects of the three doses',
#      'origin': (391.0101623535156, 519.0186767578125),
#      'bbox': (391.0101623535156,
#       512.8816528320312,
#       550.53125,
#       520.923583984375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875, 512.7939453125, 550.53125, 520.923583984375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'on median lifespans in male mice and the highest dose on median',
#      'origin': (306.707763671875, 529.9601440429688),
#      'bbox': (306.707763671875,
#       523.8231201171875,
#       550.5767211914062,
#       531.8650512695312)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     523.8231201171875,
#     550.5767211914062,
#     531.8650512695312)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'lifespan in female mice. Here, we report the completed survival analyses,',
#      'origin': (306.707763671875, 540.958984375),
#      'bbox': (306.707763671875,
#       534.8219604492188,
#       550.5307006835938,
#       542.8638916015625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     534.8219604492188,
#     550.5307006835938,
#     542.8638916015625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'including the effects on maximal lifespan.',
#      'origin': (306.707763671875, 551.9005126953125),
#      'bbox': (306.707763671875,
#       545.7634887695312,
#       449.43499755859375,
#       553.805419921875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     545.7634887695312,
#     449.43499755859375,
#     553.805419921875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Fish oil (FO) was selected for testing, at two doses, in part because',
#      'origin': (316.6856689453125, 562.842041015625),
#      'bbox': (316.6856689453125,
#       556.7050170898438,
#       550.548828125,
#       564.7469482421875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (316.6856689453125,
#     556.7050170898438,
#     550.548828125,
#     564.7469482421875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'several epidemiologic studies have associated reduced risk of cardiovas-',
#      'origin': (306.707763671875, 573.840087890625),
#      'bbox': (306.707763671875,
#       567.7030639648438,
#       550.5377807617188,
#       575.7449951171875)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     567.7030639648438,
#     550.5377807617188,
#     575.7449951171875)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'cular disease with ﬁsh or ﬁsh oil consumption (e.g. Kris-Etherton',
#      'origin': (306.707763671875, 584.7816162109375),
#      'bbox': (306.707763671875,
#       578.6445922851562,
#       528.0856323242188,
#       586.6865234375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (528.0856323242188, 584.7816162109375),
#      'bbox': (528.0856323242188,
#       578.556884765625,
#       548.2454223632812,
#       586.6865234375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ',',
#      'origin': (548.27734375, 584.7816162109375),
#      'bbox': (548.27734375,
#       578.6445922851562,
#       550.5169677734375,
#       586.6865234375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     578.556884765625,
#     550.5169677734375,
#     586.6865234375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '2002). FO has also been shown to reduce several risk factors associated',
#      'origin': (306.707763671875, 595.7230834960938),
#      'bbox': (306.707763671875,
#       589.5860595703125,
#       550.58154296875,
#       597.6279907226562)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     589.5860595703125,
#     550.58154296875,
#     597.6279907226562)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'with coronary heart disease (Sidhu, 2003) such as lowering triglyceride',
#      'origin': (306.707763671875, 606.66455078125),
#      'bbox': (306.707763671875,
#       600.5275268554688,
#       550.5375366210938,
#       608.5694580078125)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     600.5275268554688,
#     550.5375366210938,
#     608.5694580078125)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'levels (Kris-Etherton',
#      'origin': (306.707763671875, 617.6634521484375),
#      'bbox': (306.707763671875,
#       611.5264282226562,
#       375.7050476074219,
#       619.568359375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-LI',
#      'color': 2236191,
#      'ascender': 0.781000018119812,
#      'descender': -0.23899999260902405,
#      'text': ' et al.',
#      'origin': (375.7050476074219, 617.6634521484375),
#      'bbox': (375.7050476074219,
#       611.438720703125,
#       397.8956604003906,
#       619.568359375)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': ', 2002). Additionally, studies suggest that',
#      'origin': (397.87091064453125, 617.6634521484375),
#      'bbox': (397.87091064453125,
#       611.5264282226562,
#       550.519287109375,
#       619.568359375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.707763671875,
#     611.438720703125,
#     550.519287109375,
#     619.568359375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'consumption of FO or of its omega-3 fatty acids may have beneﬁcial',
#      'origin': (306.70855712890625, 628.60498046875),
#      'bbox': (306.70855712890625,
#       622.4679565429688,
#       550.5360107421875,
#       630.5098876953125)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     622.4679565429688,
#     550.5360107421875,
#     630.5098876953125)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'effects on stroke, depression, cancer, and Alzheimer’s disease (Rose &',
#      'origin': (306.70855712890625, 639.5464477539062),
#      'bbox': (306.70855712890625,
#       633.409423828125,
#       550.5250244140625,
#       641.4513549804688)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     633.409423828125,
#     550.5250244140625,
#     641.4513549804688)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Connolly, 1999; Sidhu, 2003).',
#      'origin': (306.70855712890625, 650.5445556640625),
#      'bbox': (306.70855712890625,
#       644.4075317382812,
#       409.74395751953125,
#       652.449462890625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     644.4075317382812,
#     409.74395751953125,
#     652.449462890625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'Acarbose (ACA) is an inhibitor of intestinal',
#      'origin': (316.68646240234375, 661.4860229492188),
#      'bbox': (316.68646240234375,
#       655.3489990234375,
#       465.0797424316406,
#       663.3909301757812)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSMP13',
#      'color': 2236191,
#      'ascender': 0.8019999861717224,
#      'descender': -0.3019999861717224,
#      'text': ' a',
#      'origin': (465.0797424316406, 661.4860229492188),
#      'bbox': (465.0797424316406,
#       655.0939331054688,
#       472.45684814453125,
#       663.8930053710938)},
#     {'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': '-glucosidase. It inhibits',
#      'origin': (472.4225769042969, 661.4860229492188),
#      'bbox': (472.4225769042969,
#       655.3489990234375,
#       550.5279541015625,
#       663.3909301757812)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (316.68646240234375,
#     655.0939331054688,
#     550.5279541015625,
#     663.8930053710938)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'digestion of polysaccharides and attenuates the uptake of sugars from',
#      'origin': (306.70855712890625, 672.427490234375),
#      'bbox': (306.70855712890625,
#       666.2904663085938,
#       550.5088500976562,
#       674.3323974609375)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     666.2904663085938,
#     550.5088500976562,
#     674.3323974609375)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'the GI tract. It lowers postprandial glucose excursions and is prescribed',
#      'origin': (306.70855712890625, 683.4255981445312),
#      'bbox': (306.70855712890625,
#       677.28857421875,
#       550.5823974609375,
#       685.3305053710938)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     677.28857421875,
#     550.5823974609375,
#     685.3305053710938)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'for the treatment of type 2 diabetes. It was selected for testing in part',
#      'origin': (306.70855712890625, 694.3670654296875),
#      'bbox': (306.70855712890625,
#       688.2300415039062,
#       550.5200805664062,
#       696.27197265625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     688.2300415039062,
#     550.5200805664062,
#     696.27197265625)},
#   {'spans': [{'size': 7.970200061798096,
#      'flags': 4,
#      'font': 'AdvPSFT-L',
#      'color': 2236191,
#      'ascender': 0.7699999809265137,
#      'descender': -0.23899999260902405,
#      'text': 'because it was proposed to act as a dietary restriction mimetic. In our',
#      'origin': (306.70855712890625, 705.30859375),
#      'bbox': (306.70855712890625,
#       699.1715698242188,
#       550.4906616210938,
#       707.2135009765625)}],
#    'wmode': 0,
#    'dir': (1.0, 0.0),
#    'bbox': (306.70855712890625,
#     699.1715698242188,
#     550.4906616210938,
#     707.2135009765625)}]}
